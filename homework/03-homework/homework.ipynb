# %% [markdown]
# # Module 3

# %% [markdown]
# ## Q1

# %%
from homework import *

# %% [markdown]
# ```python
# @task
# def train_model(df, categorical, logger):
#
#     train_dicts = df[categorical].to_dict(orient='records')
#     dv = DictVectorizer()
#     X_train = dv.fit_transform(train_dicts)
#     y_train = df.duration.values
#
#     logger.info(f"The shape of X_train is {X_train.shape}")
#     logger.info(f"The DictVectorizer has {len(dv.feature_names_)} features")
#
#     lr = LinearRegression()
#     lr.fit(X_train, y_train)
#     y_pred = lr.predict(X_train)
#     mse = mean_squared_error(y_train, y_pred, squared=False)
#     logger.info(f"The MSE of training is: {mse}")
#     return lr, dv
# ```
#
# **Solution**:`train_model` since its return value is a tuple.

# %% [markdown]
# ## Q2

# %%
main(date="2021-08-15")
# Out:
# 18:34:12.675 | INFO    | prefect.engine - Created flow run 'observant-peacock' for flow 'main'
# 18:34:12.676 | INFO    | Flow run 'observant-peacock' - Using task runner 'ConcurrentTaskRunner'
# 18:34:12.682 | WARNING | Flow run 'observant-peacock' - No default storage is configured on the server. Results from this flow run will be stored in a temporary directory in its runtime environment.
# 18:34:12.707 | INFO    | Flow run 'observant-peacock' - Created task run 'get_paths-d0d6dac3-0' for task 'get_paths'
# 18:34:12.732 | INFO    | Task run 'get_paths-d0d6dac3-0' - Finished in state Completed()
# 18:34:12.732 | INFO    | Flow run 'observant-peacock' - Using train_path=./data/fhv_tripdata_2021-06.parquet, valid_path=./data/fhv_tripdata_2021-07.parquet
# 18:34:12.743 | INFO    | Flow run 'observant-peacock' - Created task run 'read_data-4bc89d3c-0' for task 'read_data'
# ...

# %% [markdown]
# **Solution**: The MSE of validation is: 11.637025440324567

# %% [markdown]
# ## Q3

# %%
import os

os.path.getsize("dv-2021-08-15.b")
# Out:
# 13191

# %% [markdown]
# **Solution**: 13,000 bytes.

# %% [markdown]
# ## Q4

# %% [markdown]
# **Solution:** `0 9 15 * *`
#
# Reads 0 minutes (out of 60), hour 9 (out of 24), every 15th day of (any) month (over any dow).

# %% [markdown]
# ## Q5

# %%
from IPython.display import Image

Image('scheduled_runs.png')

# %% [markdown]
# **Solution:** 3 (choose closest)

# %% [markdown]
# ## Q6

# %%
# !prefect work-queue --help
# Out:
# Usage: prefect work-queue [OPTIONS] COMMAND [ARGS]...
#
#   Commands for work queue CRUD.
#
# Options:
#   --help  Show this message and exit.
#
# Commands:
#   clear-concurrency-limit  Clear any concurrency limits from a work queue.
#   create                   Create a work queue.
#   delete                   Delete a work queue by ID.
#   inspect                  Inspect a work queue by ID.
#   ls                       View all work queues.
#   pause                    Pause a work queue.
#   preview                  Preview a work queue.
#   resume                   Resume a paused work queue.
#   set-concurrency-limit    Set a concurrency limit on a work queue.

# %%
# !prefect work-queue ls
# Out:
#                               Work Queues
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃                                   ID ┃ Name     ┃ Concurrency Limit ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ 7476c21d-f4b4-449f-b6bf-5d79b37a7417 │ Homework │ None              │
# └──────────────────────────────────────┴──────────┴───────────────────┘
#                       (**) denotes a paused queue

# %% [markdown]
# **Solution** `prefect work-queue ls` to view all available queues.
