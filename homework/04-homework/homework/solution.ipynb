# %% [markdown]
# # Homework 4: Solution

# %%
# !pip list --format=freeze | grep scikit-learn
# Out:
# scikit-learn==1.0.2

# %%
# !python --version
# Out:
# Python 3.9.12

# %% [markdown]
# ## Q1

# %%
import pickle
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context


with open('model.bin', 'rb') as f_in:
    dv, lr = pickle.load(f_in)

categorical = ['PUlocationID', 'DOlocationID']

def read_data(filename):
    df = pd.read_parquet(filename)
    
    df['duration'] = df.dropOff_datetime - df.pickup_datetime
    df['duration'] = df.duration.dt.total_seconds() / 60

    df = df[(df.duration >= 1) & (df.duration <= 60)].copy()

    df[categorical] = df[categorical].fillna(-1).astype('int').astype('str')
    
    return df

# February 2021 FVH data.
year = 2021
month = 2
df = read_data(f'https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_{year:04d}-{month:02d}.parquet')

dicts = df[categorical].to_dict(orient='records')
X_val = dv.transform(dicts)
y_pred = lr.predict(X_val)

# %% [markdown]
# > Run this notebook for the February 2021 FVH data. What's the mean predicted duration for this dataset?

# %%
print(f'{y_pred.mean():.2f}')
# Out:
# 16.19

# %% [markdown]
# **Solution**
# * 16.19

# %% [markdown]
# ## Q2

# %%
# !pip list --format=freeze | grep pyarrow
# Out:
# pyarrow==8.0.0

# %%
# !pip list --format=freeze | grep fastparquet # Not installed

# %%
output_file = f'fhv_tripdata_{year:04d}-{month:02d}.parquet'
df['ride_id'] = f'{year:04d}/{month:02d}_' + df.index.astype('str')
df['pred'] = y_pred
df_result = df[['ride_id', 'pred']]

df_result.to_parquet(
    output_file,
    engine='pyarrow',
    compression=None,
    index=False
)

# %%
df_result.head()
# Out:
#      ride_id       pred
# 1  2021/02_1  14.539865
# 2  2021/02_2  13.740422
# 3  2021/02_3  15.593339
# 4  2021/02_4  15.188118
# 5  2021/02_5  13.817206

# %% [markdown]
# > Next, write the ride id and the predictions to a dataframe with results. Make sure you use the snippet above for saving the file. It should contain only these two columns. For this question, don't change the dtypes of the columns and use pyarrow, not fastparquet.

# %%
import os
print(f'{os.path.getsize(output_file):6e}')
# Out:
# 1.971138e+07

# %% [markdown]
# **Solution:**
# * 19M

# %% [markdown]
# ## Q3

# %% [markdown]
# > Now let's turn the notebook into a script. Which command you need to execute for that?

# %% [markdown]
# **Solution**

# %%
# !jupyter nbconvert starter.ipynb --to python
# Out:
# [NbConvertApp] Converting notebook starter.ipynb to python
# [NbConvertApp] Writing 916 bytes to starter.py

# %%
# !cat starter.py # Added a few lines to make it executable
# Out:
# #!/usr/bin/env python
# # coding: utf-8
# import pickle
# import pandas as pd
# import ssl
# ssl._create_default_https_context = ssl._create_unverified_context
#
#
# with open('model.bin', 'rb') as f_in:
#     dv, lr = pickle.load(f_in)
#
# categorical = ['PUlocationID', 'DOlocationID']
#
# def read_data(filename):
#     df = pd.read_parquet(filename)
#
#     df['duration'] = df.dropOff_datetime - df.pickup_datetime
#     df['duration'] = df.duration.dt.total_seconds() / 60
#
#     df = df[(df.duration >= 1) & (df.duration <= 60)].copy()
#
#     df[categorical] = df[categorical].fillna(-1).astype('int').astype('str')
#
#     return df
#
#
# def run(year, month):
#     df = read_data(f'https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_{year:04d}-{month:02d}.parquet')
#
#     dicts = df[categorical].to_dict(orient='records')
#     X_val = dv.transform(dicts)
#     y_pred = lr.predict(X_val)
#
#     print(y_pred.mean())
#
#
# if __name__ == "__main__":
#     import argparse
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--year", type=int)
#     parser.add_argument("--month", type=int)
#     args = parser.parse_args()
#
#     run(args.year, args.month)

# %% [markdown]
# ## Q4

# %% [markdown]
# > What's the first hash for the Scikit-Learn dependency?

# %%
pipfile_lock = {
    "scikit-learn": {
            "hashes": [
                "sha256:08ef968f6b72033c16c479c966bf37ccd49b06ea91b765e1cc27afefe723920b",
                "sha256:158faf30684c92a78e12da19c73feff9641a928a8024b4fa5ec11d583f3d8a87",
                "sha256:16455ace947d8d9e5391435c2977178d0ff03a261571e67f627c8fee0f9d431a",
                "sha256:245c9b5a67445f6f044411e16a93a554edc1efdcce94d3fc0bc6a4b9ac30b752",
                "sha256:285db0352e635b9e3392b0b426bc48c3b485512d3b4ac3c7a44ec2a2ba061e66",
                "sha256:2f3b453e0b149898577e301d27e098dfe1a36943f7bb0ad704d1e548efc3b448",
                "sha256:46f431ec59dead665e1370314dbebc99ead05e1c0a9df42f22d6a0e00044820f",
                "sha256:55f2f3a8414e14fbee03782f9fe16cca0f141d639d2b1c1a36779fa069e1db57",
                "sha256:5cb33fe1dc6f73dc19e67b264dbb5dde2a0539b986435fdd78ed978c14654830",
                "sha256:75307d9ea39236cad7eea87143155eea24d48f93f3a2f9389c817f7019f00705",
                "sha256:7626a34eabbf370a638f32d1a3ad50526844ba58d63e3ab81ba91e2a7c6d037e",
                "sha256:7a93c1292799620df90348800d5ac06f3794c1316ca247525fa31169f6d25855",
                "sha256:7d6b2475f1c23a698b48515217eb26b45a6598c7b1840ba23b3c5acece658dbb",
                "sha256:80095a1e4b93bd33261ef03b9bc86d6db649f988ea4dbcf7110d0cded8d7213d",
                "sha256:85260fb430b795d806251dd3bb05e6f48cdc777ac31f2bcf2bc8bbed3270a8f5",
                "sha256:9369b030e155f8188743eb4893ac17a27f81d28a884af460870c7c072f114243",
                "sha256:a053a6a527c87c5c4fa7bf1ab2556fa16d8345cf99b6c5a19030a4a7cd8fd2c0",
                "sha256:a90b60048f9ffdd962d2ad2fb16367a87ac34d76e02550968719eb7b5716fd10",
                "sha256:a999c9f02ff9570c783069f1074f06fe7386ec65b84c983db5aeb8144356a355",
                "sha256:b1391d1a6e2268485a63c3073111fe3ba6ec5145fc957481cfd0652be571226d",
                "sha256:b54a62c6e318ddbfa7d22c383466d38d2ee770ebdb5ddb668d56a099f6eaf75f",
                "sha256:b5870959a5484b614f26d31ca4c17524b1b0317522199dc985c3b4256e030767",
                "sha256:bc3744dabc56b50bec73624aeca02e0def06b03cb287de26836e730659c5d29c",
                "sha256:d93d4c28370aea8a7cbf6015e8a669cd5d69f856cc2aa44e7a590fb805bb5583",
                "sha256:d9aac97e57c196206179f674f09bc6bffcd0284e2ba95b7fe0b402ac3f986023",
                "sha256:da3c84694ff693b5b3194d8752ccf935a665b8b5edc33a283122f4273ca3e687",
                "sha256:e174242caecb11e4abf169342641778f68e1bfaba80cd18acd6bc84286b9a534",
                "sha256:eabceab574f471de0b0eb3f2ecf2eee9f10b3106570481d007ed1c84ebf6d6a1",
                "sha256:f14517e174bd7332f1cca2c959e704696a5e0ba246eb8763e6c24876d8710049",
                "sha256:fa38a1b9b38ae1fad2863eff5e0d69608567453fdfc850c992e6e47eb764e846",
                "sha256:ff3fa8ea0e09e38677762afc6e14cad77b5e125b0ea70c9bba1992f02c93b028",
                "sha256:ff746a69ff2ef25f62b36338c615dd15954ddc3ab8e73530237dd73235e76d62"
            ],
            "index": "pypi",
            "version": "==1.0.2"
    },
}

# %% [markdown]
# **Solution:**

# %%
print(pipfile_lock['scikit-learn']['hashes'][0])
# Out:
# sha256:08ef968f6b72033c16c479c966bf37ccd49b06ea91b765e1cc27afefe723920b

# %% [markdown]
# ## Q5

# %%
# !python starter.py --year=2021 --month=3
# Out:
# 16.298821614015107

# %% [markdown]
# **Solution:**
# * 16.29

# %% [markdown]
# ## Q6

# %%
# !cat Dockerfile
# Out:
# FROM agrigorev/zoomcamp-model:mlops-3.9.7-slim
#
# WORKDIR /app
#
# RUN pip install -U pip
# RUN pip install pipenv
#
# COPY [ "starter.py", "starter.py", "./"]
#
# COPY [ "Pipfile", "Pipfile.lock", "./" ]
#
# RUN pipenv install --system --deploy
#
# ENTRYPOINT [ "python", "./starter.py" ]

# %%
# !docker build -t homework4 .
# Out:
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.1s
# [+] Building 0.3s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
# [+] Building 0.4s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.4s
# [+] Building 0.6s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.5s
# [+] Building 0.8s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.7s
# [+] Building 0.9s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.8s
# [+] Building 1.1s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.0s
# [+] Building 1.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.1s
# [+] Building 1.3s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           0.0s
# [+] Building 1.5s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           0.2s
# [+] Building 1.6s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           0.3s
# [+] Building 1.8s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           0.5s
# [+] Building 1.9s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           0.6s
# [+] Building 2.1s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           0.8s
# [+] Building 2.2s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           0.9s
# [+] Building 2.4s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           1.1s
# [+] Building 2.5s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           1.2s
# [+] Building 2.7s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           1.4s
# [+] Building 2.8s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           1.5s
# [+] Building 3.0s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           1.7s
# [+] Building 3.1s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           1.8s
# [+] Building 3.3s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           2.0s
# [+] Building 3.4s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           2.1s
# [+] Building 3.6s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           2.3s
# [+] Building 3.7s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           2.4s
# [+] Building 3.9s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           2.6s
# [+] Building 4.0s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           2.7s
# [+] Building 4.2s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           2.9s
# [+] Building 4.3s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           3.0s
# [+] Building 4.5s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           3.2s
# [+] Building 4.6s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           3.3s
# [+] Building 4.8s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           3.5s
# [+] Building 4.9s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           3.6s
# [+] Building 5.1s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           3.8s
# [+] Building 5.2s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           3.9s
# [+] Building 5.4s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           4.1s
# [+] Building 5.5s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           4.2s
# [+] Building 5.7s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           4.4s
# [+] Building 5.8s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           4.5s
# [+] Building 6.0s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           4.7s
# [+] Building 6.1s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           4.8s
# [+] Building 6.3s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           5.0s
# [+] Building 6.4s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           5.1s
# [+] Building 6.6s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           5.3s
# [+] Building 6.7s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           5.4s
# [+] Building 6.9s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           5.6s
# [+] Building 7.0s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           5.7s
# [+] Building 7.2s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           5.9s
# [+] Building 7.3s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           6.1s
# [+] Building 7.5s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           6.2s
# [+] Building 7.6s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           6.4s
# [+] Building 7.8s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           6.5s
# [+] Building 7.9s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           6.7s
# [+] Building 8.1s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           6.8s
# [+] Building 8.3s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           7.0s
# [+] Building 8.4s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           7.1s
# [+] Building 8.6s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           7.3s
# [+] Building 8.7s (6/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                           7.4s
# ...
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            19.0s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27
# [+] Building 100.2s (10/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            19.1s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27
# [+] Building 100.3s (10/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            19.3s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27
# [+] Building 100.5s (10/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            19.4s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27
# [+] Building 100.6s (10/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            19.6s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27
# [+] Building 100.8s (10/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            19.7s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27
# [+] Building 100.9s (10/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            19.9s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27
# [+] Building 101.1s (10/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            20.0s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27
# [+] Building 101.2s (10/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            20.2s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27
# [+] Building 101.4s (10/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            20.3s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27
# [+] Building 101.5s (10/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            20.5s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27
# [+] Building 101.7s (10/11)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 92B                                           0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-3.9.7-slim@sha256  0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => [3/7] RUN pip install -U pip                                          41.7s
#  => [4/7] RUN pip install pipenv                                          37.9s
#  => [5/7] COPY [ starter.py, starter.py, ./]                               0.1s
#  => [6/7] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.0s
#  => [7/7] RUN pipenv install --system --deploy                            20.6s
#  => => # Installing dependencies from Pipfile.lock (2ea4c6)...
#  => => #   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 7/111 — 00:00:27

# %% [markdown]
# > Now run the script with docker. What's the mean predicted duration for April 2021?

# %%
# !docker run -it --rm homework4:latest --year=2021 --month=4
# Out:
# 9.967573179784523

# %% [markdown]
# **Solution**
# * 9.96
